# %% [markdown]
# <table style="float:left; border:none">
#    <tr style="border:none">
#        <td style="border:none">
#            <img
#                src="../images/EmpleaFidelidad.png"
#                style="width:200px"
#            >
#            </a>
#        </td>
#    </tr>
# </table>
# <div style="float:right;font-size: 20px;"><h2>IBM - 05 - ENN (EditedNearestNeighbours) Random Forest Classifier</h2></div>

# %% [markdown]
# <a id="top"></a> <br>
# ## Índice
# 1. [Carga de paquetes y datos](#1)<br>
#     1.1. [Librerías y clases](#11)<br>
#     1.2. [Lectura de datos](#12)<br>
#     1.3. [Filtrado de variable target](#13)<br>
# 2. [Modelo](#2)<br>
#     2.1. [Separación en train y test](#21)<br>
#     2.2. [Target encoding](#22)<br>
#     2.3. [Métrica para optimización de hiperparámetros](#23)<br>
#     2.4. [Preprocesamiento](#24)<br>
#     2.5. [Pipe modelo](#25)<br>
#     2.6. [Optimización de hiperparámetros con Optuna](#26)<br>
#     2.7. [Visualización de hiperparámetros](#27)<br>
#     2.8. [Entrenamiento del modelo con mejores hiperparámetros](#28)<br>
# 3. [Evaluación del modelo](#3)<br>
#     3.1. [Métricas principales](#31)<br>
#     3.2. [Reporte de clasificación](#32)<br>
#     3.3. [Matriz de confusión](#33)<br>
#     3.4. [ROC curve](#34)<br>
#     3.5. [Precission-Recall Curve](#35)<br>
#     3.6. [Feature importance](#36)<br>
# 4. [Exportación con Shelve](#4)<br>
#     4.1. [Exportación con Shelve](#41)<br>

# %% [markdown]
# ***
# <a id="1"></a> <br>
# ## 1. Carga de paquetes y datos

# %% [markdown]
# <a id="11"></a>
# ### 1.1. Librerías y clases

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib. pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import *
from sklearn import preprocessing
from sklearn.compose import ColumnTransformer, make_column_selector
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder, StandardScaler,  FunctionTransformer, LabelEncoder, binarize
from sklearn.pipeline import make_pipeline, make_union
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.model_selection import GridSearchCV, StratifiedKFold, cross_val_score
from sklearn import tree
from sklearn.naive_bayes import GaussianNB
from imblearn.pipeline import Pipeline 
from sklearn.inspection import permutation_importance
from imblearn.over_sampling import SMOTE
import shelve
import plotly.io as pio
pio.renderers.default = 'iframe'
import optuna
from imblearn.under_sampling import EditedNearestNeighbours

import warnings
warnings.filterwarnings("ignore")
# Out:
# C:\Users\gtoso\anaconda3\envs\dhproyect\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Esta clase permite dropear columnas de un DataFrame dentro de un pipeline

class ColumnDropper(BaseEstimator, TransformerMixin):
    def __init__(self,columns):
        self.columns=columns

    def transform(self,X,y=None):
        return X.drop(self.columns,axis=1)

    def fit(self, X, y=None):
        return self

# %% [markdown]
# <a id="12"></a>
# ### 1.2. Lecura de datos

# %%
# Carga de dataset
key= "ibm.clean.Education.csv"
path="../Data/"
df = pd.read_csv(path + key)
df.sample(3)
# Out:
#       EmployeeID  Age  Attrition     BusinessTravel              Department  \
# 1539        2043   42          0  Travel_Frequently  Research & Development
# 2072        3565   46          0      Travel_Rarely  Research & Development
# 1188        1943   42          0  Travel_Frequently  Research & Development
#
#       DistanceFromHome      Education EducationField  EnvironmentSatisfaction  \
# 1539                 2  Below college        Medical                        2
# 2072                15        College  Life Sciences                        4
# 1188                 2       Bachelor  Life Sciences                        2
#
#      Gender  ...  StockOptionLevel  TotalWorkingYears TrainingTimesLastYear  \
# 1539   Male  ...                 0                  8                     2
# 2072   Male  ...                 1                 25                     2
# 1188   Male  ...                 1                  6                     3
#
#       WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 1539                3              2                   1
# 2072                3              4                   2
# 1188                3              6                   5
#
#       YearsSinceLastPromotion YearsWithCurrManager  Employee Source  \
# 1539                        2                    2             Seek
# 2072                        0                    3           Indeed
# 1188                        1                    3  Company Website
#
#       AgeStartedWorking
# 1539                 34
# 2072                 21
# 1188                 36
#
# [3 rows x 31 columns]

# %% [markdown]
# <a id="13"></a>
# ### 1.3. Filtrado de variable target

# %% [markdown]
# **Se eliminan todas las instancias con valor de Attrition igual a "Terminated" ya que el modelo estima la probabilidad de que un empleado renuncie a la compañia**

# %%
#Elimino las instancias con valor "Termination" de la columna "Attrition"
df = df[df["Attrition"] != "Termination"]

# %% [markdown]
# ***
# <a id="2"></a> <br>
# ## 2. Modelo

# %% [markdown]
# <a id="21"></a>
# ### 2.1. Separación en train y test

# %%
# Separacion en train y test
# Selección de variable targuet
y = df.Attrition
# Selección de features
X = df.drop(["Attrition"], axis = 1)

# Separación en train y test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 161, stratify= y)

# Verificación de distribución de variable targuet en train y test
print("Distribución de variable target en Train \n", y_train.value_counts(normalize=True))
print("========================================")
print("Distribución de variable target en Test \n", y_test.value_counts(normalize=True))
# Out:
# Distribución de variable target en Train
#  0    0.842728
# 1    0.157272
# Name: Attrition, dtype: float64
# ========================================
# Distribución de variable target en Test
#  0    0.84279
# 1    0.15721
# Name: Attrition, dtype: float64

# %% [markdown]
# <a id="22"></a>
# ### 2.2. Target Encoding

# %%
# Transformación de variable targuet categórica en numérica
le = preprocessing.LabelEncoder()
y_train = le.fit_transform(y_train)
y_test = le.transform(y_test)

# %% [markdown]
# <a id="23"></a>
# ### 2.3. Métrica para optimización de hiperparámetros

# %% [markdown]
# <table style="float:center; border:none">
#    <tr style="border:none">
#        <td style="border:none">
#            <img
#                src="../images/F2score.png"
#                style="width:500"
#            >
#            </a>
#        </td>
#    </tr>
# </table>

# %%
# Creacion de score f2 
ftwo_scorer = make_scorer(fbeta_score, beta=2)

# %% [markdown]
# <a id="24"></a>
# ### 2.4. Preprocesamiento

# %%
# Definimos las columnas segun su tipo

#Features categoricas ordinales
ordinal_categorical_features= ["BusinessTravel", "Education"]

BusinessTravel=["Non-Travel","Travel_Rarely","Travel_Frequently"]
Education= ["Below college","College","Bachelor","Master","Doctor"]

categories=[BusinessTravel,Education]

#Features categoricas nominales
nominal_categorical_features=["Department", "EducationField","Gender","JobRole","OverTime","Employee Source","MaritalStatus"]

#Features numericas
numeric_features= ["DistanceFromHome","MonthlyIncome"]

#Features de otro tipo (no se va a transformar de ninguna forma)
other_features=["Age","EnvironmentSatisfaction","JobInvolvement","JobLevel","JobSatisfaction","NumCompaniesWorked","PercentSalaryHike",
               "PerformanceRating","RelationshipSatisfaction","StockOptionLevel","TotalWorkingYears","TrainingTimesLastYear","WorkLifeBalance",
               "YearsAtCompany","YearsInCurrentRole","YearsSinceLastPromotion","YearsWithCurrManager","AgeStartedWorking"]


# Creamos los transformadores para cada tipo de dato
ordinal_transformer = OrdinalEncoder(categories = categories, handle_unknown =  "use_encoded_value", unknown_value= np.nan)
nominal_transformer = OneHotEncoder(handle_unknown='ignore')
numeric_transformer = StandardScaler()

# Creamos el preprocesador
preprocessor = ColumnTransformer([
        ('ord', ordinal_transformer, ordinal_categorical_features),
        ('nom', nominal_transformer, nominal_categorical_features),
        ('num', numeric_transformer, numeric_features),
        ('other', 'passthrough', other_features)  # No hacemos nada con 'other'
    ])

# %% [markdown]
# <a id="25"></a>
# ### 2.5. Pipe modelo

# %%
pipe = Pipeline([
    ("column_dropper", ColumnDropper(["EmployeeID"])), 
    ("preprocessor", preprocessor),
      ("enn", EditedNearestNeighbours()),  # ENN para undersampling
    ("rforest", RandomForestClassifier(random_state = 42))
])

pipe
# Out:
# Pipeline(steps=[('column_dropper', ColumnDropper(columns=['EmployeeID'])),
#                 ('preprocessor',
#                  ColumnTransformer(transformers=[('ord',
#                                                   OrdinalEncoder(categories=[['Non-Travel',
#                                                                               'Travel_Rarely',
#                                                                               'Travel_Frequently'],
#                                                                              ['Below '
#                                                                               'college',
#                                                                               'College',
#                                                                               'Bachelor',
#                                                                               'Master',
#                                                                               'Doctor']],
#                                                                  handle_unknown='use_encoded_value',
#                                                                  unknown_value=nan),
#                                                   ['BusinessTravel',
#                                                    'Education'])...
#                                                    'NumCompaniesWorked',
#                                                    'PercentSalaryHike',
#                                                    'PerformanceRating',
#                                                    'RelationshipSatisfaction',
#                                                    'StockOptionLevel',
#                                                    'TotalWorkingYears',
#                                                    'TrainingTimesLastYear',
#                                                    'WorkLifeBalance',
#                                                    'YearsAtCompany',
#                                                    'YearsInCurrentRole',
#                                                    'YearsSinceLastPromotion',
#                                                    'YearsWithCurrManager',
#                                                    'AgeStartedWorking'])])),
#                 ('enn', EditedNearestNeighbours()),
#                 ('rforest', RandomForestClassifier(random_state=42))])

# %% [markdown]
# <a id="26"></a>
# ### 2.6. Optimización de hiperparámetros con Optuna

# %%
# Función objetivo de optuna

def objective_pipe(trial):
    
    #===============================================================================================================#
    #HIPERPARAMETROS DEL PIPE
    n_estimators_rforest = trial.suggest_int("n_estimators_rforest", 10, 500) # rforest
    max_depth_rforest = trial.suggest_int("max_depth_rforest", 15, 40) # rforest
    max_samples_rforest = trial.suggest_float("max_samples_rforest", 0.1, 0.9) # rforest
    max_features_rforest = trial.suggest_categorical("max_features_rforest", ["sqrt", "log2", None]) # rforest
    
    sampling_strategy_enn = trial.suggest_categorical("sampling_strategy_enn",["majority","not minority","not majority"]) #enn
    n_neighbors_enn= trial.suggest_int("n_neighbors_enn", 10, 15) #enn    
    
    
    # Pipeline modelo
    pipe = Pipeline([
         ("column_dropper", ColumnDropper(["EmployeeID"])),
        ("preprocessor", preprocessor),
         ("enn", EditedNearestNeighbours()),  # ENN para undersampling
        ("rforest", RandomForestClassifier(random_state = 42,class_weight='balanced', max_depth = max_depth_rforest,
                                       n_estimators = n_estimators_rforest, max_samples = max_samples_rforest,
                                                  max_features = max_features_rforest ))])
    # Cross validation
    kfold=StratifiedKFold(n_splits=3, random_state=1,shuffle=True)    
    
    # Return
    return cross_val_score(pipe, X_train, y_train, cv=kfold, scoring=ftwo_scorer).mean()

# %%
# %%time
models=[]
scores=[]
pipe_study = optuna.create_study(direction='maximize')
pipe_study.optimize(objective_pipe, n_trials=10)
model='rforest'
score=pipe_study.best_trial.value
models.append(model)
scores.append(score)
# Out:
# [I 2024-06-09 19:04:22,341] A new study created in memory with name: no-name-21d34abf-8763-4574-aa81-b0915e73470a
# [I 2024-06-09 19:04:23,783] Trial 0 finished with value: 0.1852063587583371 and parameters: {'n_estimators_rforest': 119, 'max_depth_rforest': 31, 'max_samples_rforest': 0.44062663325584117, 'max_features_rforest': 'sqrt', 'sampling_strategy_enn': 'not minority', 'n_neighbors_enn': 15}. Best is trial 0 with value: 0.1852063587583371.
# [I 2024-06-09 19:04:24,744] Trial 1 finished with value: 0.15778839476418102 and parameters: {'n_estimators_rforest': 80, 'max_depth_rforest': 28, 'max_samples_rforest': 0.4507807061531842, 'max_features_rforest': 'log2', 'sampling_strategy_enn': 'not minority', 'n_neighbors_enn': 10}. Best is trial 0 with value: 0.1852063587583371.
# [I 2024-06-09 19:04:27,681] Trial 2 finished with value: 0.23290615814119717 and parameters: {'n_estimators_rforest': 240, 'max_depth_rforest': 29, 'max_samples_rforest': 0.3010219510668174, 'max_features_rforest': None, 'sampling_strategy_enn': 'not majority', 'n_neighbors_enn': 12}. Best is trial 2 with value: 0.23290615814119717.
# [I 2024-06-09 19:04:28,670] Trial 3 finished with value: 0.19806661789729077 and parameters: {'n_estimators_rforest': 85, 'max_depth_rforest': 33, 'max_samples_rforest': 0.8445934572434758, 'max_features_rforest': 'sqrt', 'sampling_strategy_enn': 'not majority', 'n_neighbors_enn': 10}. Best is trial 2 with value: 0.23290615814119717.
# [I 2024-06-09 19:04:31,368] Trial 4 finished with value: 0.13881759977354 and parameters: {'n_estimators_rforest': 449, 'max_depth_rforest': 34, 'max_samples_rforest': 0.4048477872899422, 'max_features_rforest': 'log2', 'sampling_strategy_enn': 'majority', 'n_neighbors_enn': 13}. Best is trial 2 with value: 0.23290615814119717.
# [I 2024-06-09 19:04:36,081] Trial 5 finished with value: 0.2726664598642137 and parameters: {'n_estimators_rforest': 280, 'max_depth_rforest': 40, 'max_samples_rforest': 0.6503184860871876, 'max_features_rforest': None, 'sampling_strategy_enn': 'majority', 'n_neighbors_enn': 15}. Best is trial 5 with value: 0.2726664598642137.
# [I 2024-06-09 19:04:38,087] Trial 6 finished with value: 0.17101036588631194 and parameters: {'n_estimators_rforest': 267, 'max_depth_rforest': 34, 'max_samples_rforest': 0.7601718187514158, 'max_features_rforest': 'log2', 'sampling_strategy_enn': 'not minority', 'n_neighbors_enn': 11}. Best is trial 5 with value: 0.2726664598642137.
# [I 2024-06-09 19:04:40,030] Trial 7 finished with value: 0.1772316834708316 and parameters: {'n_estimators_rforest': 264, 'max_depth_rforest': 31, 'max_samples_rforest': 0.6761361635211494, 'max_features_rforest': 'log2', 'sampling_strategy_enn': 'majority', 'n_neighbors_enn': 15}. Best is trial 5 with value: 0.2726664598642137.
# [I 2024-06-09 19:04:41,023] Trial 8 finished with value: 0.16332431366514533 and parameters: {'n_estimators_rforest': 110, 'max_depth_rforest': 15, 'max_samples_rforest': 0.4720730857427551, 'max_features_rforest': 'log2', 'sampling_strategy_enn': 'majority', 'n_neighbors_enn': 14}. Best is trial 5 with value: 0.2726664598642137.
# [I 2024-06-09 19:04:42,278] Trial 9 finished with value: 0.18500060235088947 and parameters: {'n_estimators_rforest': 139, 'max_depth_rforest': 23, 'max_samples_rforest': 0.7024046743663734, 'max_features_rforest': 'log2', 'sampling_strategy_enn': 'not majority', 'n_neighbors_enn': 15}. Best is trial 5 with value: 0.2726664598642137.
# CPU times: total: 34.3 s
# Wall time: 19.9 s

# %%
print('Number of finished trials:', len(pipe_study.trials))
print('Best trial: score {}, params {}'.format(pipe_study.best_trial.value, pipe_study.best_trial.params))
# Out:
# Number of finished trials: 10
# Best trial: score 0.2726664598642137, params {'n_estimators_rforest': 280, 'max_depth_rforest': 40, 'max_samples_rforest': 0.6503184860871876, 'max_features_rforest': None, 'sampling_strategy_enn': 'majority', 'n_neighbors_enn': 15}

# %% [markdown]
# <a id="27"></a>
# ### 2.7. Visualización de hiperparámetros

# %%
optuna.visualization.plot_optimization_history(pipe_study)
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_13.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
optuna.visualization.plot_parallel_coordinate(pipe_study)
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_14.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
optuna.visualization.plot_slice(pipe_study)
# Out:
# <iframe
#     scrolling="no"
#     width="1820px"
#     height="545px"
#     src="iframe_figures/figure_15.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
optuna.visualization.plot_param_importances(pipe_study)
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_16.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
optuna.visualization.plot_edf(pipe_study)
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_17.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
optuna.visualization.plot_contour(pipe_study)
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_18.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# <a id="28"></a>
# ### 2.8.Entrenamiento del modelo con mejores hiperparámetros

# %%
#Mejores Hiperparámetros del estudio
pipe_study.best_trial.params
# Out:
# {'n_estimators_rforest': 280,
#  'max_depth_rforest': 40,
#  'max_samples_rforest': 0.6503184860871876,
#  'max_features_rforest': None,
#  'sampling_strategy_enn': 'majority',
#  'n_neighbors_enn': 15}

# %%
# Seteado de mejores hiperparametros en el pipeline
best_params = {
                "rforest__n_estimators" : pipe_study.best_trial.params["n_estimators_rforest"],
               "rforest__max_depth" : pipe_study.best_trial.params["max_depth_rforest"],
               "rforest__max_samples" : pipe_study.best_trial.params["max_samples_rforest"],
                "enn__sampling_strategy": pipe_study.best_trial.params["sampling_strategy_enn"],
                "enn__n_neighbors": pipe_study.best_trial.params["n_neighbors_enn"]}

pipe.set_params(**best_params)
# Out:
# Pipeline(steps=[('column_dropper', ColumnDropper(columns=['EmployeeID'])),
#                 ('preprocessor',
#                  ColumnTransformer(transformers=[('ord',
#                                                   OrdinalEncoder(categories=[['Non-Travel',
#                                                                               'Travel_Rarely',
#                                                                               'Travel_Frequently'],
#                                                                              ['Below '
#                                                                               'college',
#                                                                               'College',
#                                                                               'Bachelor',
#                                                                               'Master',
#                                                                               'Doctor']],
#                                                                  handle_unknown='use_encoded_value',
#                                                                  unknown_value=nan),
#                                                   ['BusinessTravel',
#                                                    'Education'])...
#                                                    'TotalWorkingYears',
#                                                    'TrainingTimesLastYear',
#                                                    'WorkLifeBalance',
#                                                    'YearsAtCompany',
#                                                    'YearsInCurrentRole',
#                                                    'YearsSinceLastPromotion',
#                                                    'YearsWithCurrManager',
#                                                    'AgeStartedWorking'])])),
#                 ('enn',
#                  EditedNearestNeighbours(n_neighbors=15,
#                                          sampling_strategy='majority')),
#                 ('rforest',
#                  RandomForestClassifier(max_depth=40,
#                                         max_samples=0.6503184860871876,
#                                         n_estimators=280, random_state=42))])

# %%
#Entrenamiento del modelo con los mejores hiperparámetros
model = pipe.fit(X_train, y_train)

# %% [markdown]
# ***
# <a id="3"></a> <br>
# ## 3. Evaluación del modelo

# %% [markdown]
# <a id="31"></a>
# ### 3.1. Métricas principales

# %%
#predicciones train y test
model_pred_train = model.predict(X_train)
model_pred_test= model.predict(X_test)
#==========================

ftwo_train = fbeta_score(y_train, model_pred_train, beta = 2)
ftwo_test = fbeta_score(y_test ,model_pred_test, beta = 2)

fone_train = f1_score(y_train, model_pred_train)
fone_test = f1_score(y_test, model_pred_test)

accuracy_train = accuracy_score(y_train, model_pred_train)
accuracy_test = accuracy_score(y_test, model_pred_test)

ROC_train = roc_auc_score(y_train, model_pred_train)
ROC_test = roc_auc_score(y_test, model_pred_test)

recall_train = recall_score(y_train, model_pred_train)
recall_test = recall_score(y_test, model_pred_test)

precision_train = precision_score(y_train, model_pred_train)
precision_test = precision_score(y_test, model_pred_test)

# %%
df_metricas = pd.DataFrame({'Models': ['ENN Random Forest'],
                       'F2 Score Train':  [ftwo_train],
                       'F2 Score Test': [ftwo_test],
                       'F1 Score Train':  [fone_train],
                       'F1 Score Test': [fone_test],                       
                       'Accuracy Score Train':  [accuracy_train],
                       'Accuracy Score Test': [accuracy_test],
                       'ROC AUC Score Train':  [ROC_train],
                       'ROC AUC Score Test': [ROC_test],
                       'Recall Score Train':  [recall_train],
                       'Recall Score Test': [recall_test],
                      "Precision Score Train" : [precision_train],
                      "Precision Score Test" : [precision_test]})
df_metricas
# Out:
#               Models  F2 Score Train  F2 Score Test  F1 Score Train  \
# 0  ENN Random Forest        0.690789       0.488445         0.47191
#
#    F1 Score Test  Accuracy Score Train  Accuracy Score Test  \
# 0       0.336347              0.648009             0.566194
#
#    ROC AUC Score Train  ROC AUC Score Test  Recall Score Train  \
# 0              0.79116            0.620311                 1.0
#
#    Recall Score Test  Precision Score Train  Precision Score Test
# 0           0.699248               0.308824              0.221429

# %% [markdown]
# <a id="32"></a>
# ### 3.2. Reporte de clasificación

# %%
print(classification_report(y_test,model_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.54      0.68       713
#            1       0.22      0.70      0.34       133
#
#     accuracy                           0.57       846
#    macro avg       0.56      0.62      0.51       846
# weighted avg       0.80      0.57      0.62       846

# %% [markdown]
# <a id="33"></a> <br>
# ### 3.3. Matriz de confusión

# %%
# Matriz de confusión para modelo seleccionado
conf_matrix = confusion_matrix(y_train, model_pred_train)
f, ax = plt.subplots(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, fmt="d", linewidths=.6, ax=ax)
plt.title("Confusion Matrix Random Forest Train", fontsize=20)
plt.subplots_adjust(left=0.15, right=0.99, bottom=0.15, top=0.99)
ax.set_yticks(np.arange(conf_matrix.shape[0]) + 0.5, minor=False)
ax.set_xticklabels(['Pred Negatives', 'Pred Positives'],fontsize=16, rotation=360)
ax.set_yticklabels(['Actual Negatives', 'Actual Positives'], fontsize=16, rotation=360)
plt.show()

conf_matrix = confusion_matrix(y_test, model_pred_test)
f, ax = plt.subplots(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, fmt="d", linewidths=.6, ax=ax)
plt.title("Confusion Matrix Random Forest Test", fontsize=20)
plt.subplots_adjust(left=0.15, right=0.99, bottom=0.15, top=0.99)
ax.set_yticks(np.arange(conf_matrix.shape[0]) + 0.5, minor=False)
ax.set_xticklabels(['Pred Negatives', 'Pred Positives'],fontsize=16, rotation=360)
ax.set_yticklabels(['Actual Negatives', 'Actual Positives'], fontsize=16, rotation=360)
plt.show()

# %% [markdown]
# <a id="34"></a> <br>
# ### 3.4. ROC Curve

# %%
# Obtención de probabilidades de test
probsdmodel_rforest = model.predict_proba(X_test)
predsdmodel_rforest = probsdmodel_rforest[:,1]


# Generación de ROC curve
model_false_positive_rate , model_true_positive_rate , model_threshold = roc_curve(y_test , predsdmodel_rforest)



# Gráfico curva ROC
sns.set_style('whitegrid')
plt.figure(figsize=(18,10))
plt.title('Reciver Operating Characterstic Curve')

plt.plot(model_false_positive_rate , model_true_positive_rate,label="Random Forest")


plt.plot([0,1],ls='--')
plt.plot([0,0],[1,0],c='.5')
plt.plot([1,1],c='.5')
plt.ylabel('True positive rate')
plt.xlabel('False positive rate')
plt.legend()
plt.show()

# %% [markdown]
# <a id="35"></a> <br>
# ### 3.5. Precission-Recall Curve

# %%
probsdmodel_rforest = model.predict_proba(X_test)
predsdmodel_rforest = probsdmodel_rforest[:,1]

# Generación métricas precision, recall 
rforest_precision , rforest_recall , rforest_threshold = precision_recall_curve(y_test , predsdmodel_rforest)


# Gráfico curva precision recall curve
sns.set_style('whitegrid')
plt.figure(figsize=(18,10))
plt.title('Precision Recall Curve')

plt.plot(rforest_recall , rforest_precision,label="Random Forest")


plt.plot([0,0],[1,0],c='.5')
plt.plot([1,1],c='.5')
plt.ylabel('Precision')
plt.xlabel('Recall')
plt.legend()
plt.show()

# %% [markdown]
# <a id="36"></a> <br>
# ### 3.6. Feature importance

# %%
# Se busca la feature importance con permutation importance
feature_importance = permutation_importance(model, X_test, y_test, n_repeats=5, random_state=0)

# %%
# Se crea un dataframe de features importances
importancia_features = pd.DataFrame(feature_importance["importances_mean"], index = X_test.columns, columns=['importancia'])
importancia_features_sort = importancia_features.sort_values('importancia', ascending=False)
importancia_features_sort = importancia_features_sort[importancia_features_sort.importancia != 0]
display(importancia_features_sort)
# Out:
#                           importancia
# Age                          0.040898
# AgeStartedWorking            0.010402
# Department                   0.008983
# OverTime                     0.007329
# DistanceFromHome             0.003783
# WorkLifeBalance              0.000946
# JobSatisfaction              0.000709
# RelationshipSatisfaction     0.000473
# JobRole                      0.000236
# YearsAtCompany              -0.000473
# Education                   -0.000709
# MonthlyIncome               -0.000946
# PerformanceRating           -0.000946
# Employee Source             -0.000946
# YearsSinceLastPromotion     -0.001182
# YearsWithCurrManager        -0.001891
# NumCompaniesWorked          -0.002837
# TrainingTimesLastYear       -0.002837
# BusinessTravel              -0.002837
# StockOptionLevel            -0.003073
# YearsInCurrentRole          -0.003310
# EnvironmentSatisfaction     -0.003546
# EducationField              -0.004019
# JobInvolvement              -0.004965
# JobLevel                    -0.007329
# PercentSalaryHike           -0.008274
# Gender                      -0.008274
# MaritalStatus               -0.015839
# TotalWorkingYears           -0.023168

# %%
# Creating a seaborn bar plot

f, ax = plt.subplots(figsize=(20, 8))
ax = sns.barplot(x=importancia_features_sort.importancia, y=importancia_features_sort.index, data=importancia_features_sort)
ax.set_title("Visualize feature scores of the features",fontsize=20)
ax.set_yticklabels(importancia_features_sort.index, fontsize=12)
ax.set_xlabel("Feature importance score",fontsize=15)
ax.set_ylabel("Features",fontsize=15)
plt.show()

# %% [markdown]
# ***
# <a id="4"></a> <br>
# ## 4. Exportación con Shelve

# %% [markdown]
# <a id="41"></a> <br>
# ### 4.1. Exportación con Shelve

# %%
ENNrforest = shelve.open('../Models Shelve/05.ENN_RandomForest.db')

ENNrforest['modelo'] = model
ENNrforest["metricas"] = df_metricas

ENNrforest.close()
